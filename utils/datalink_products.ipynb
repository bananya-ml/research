# %%
from astropy.table import Table
from astroquery.gaia import Gaia
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io.votable import parse_single_table

# %%
def chunks(lst, n):
    ""
    "Split an input list into multiple chunks of size =< n"
    ""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def extract_dl_ind(datalink_dict, key, figsize = [15,5], fontsize = 12, linewidth = 2, show_legend = True, show_grid = True):
    ""
    "Extract individual DataLink products and export them to an Astropy Table"
    ""    
    for i in datalink_dict[key]:   
        dl_out  = i.to_table()
        if 'time' in dl_out.keys():
            plot_e_phot(dl_out, colours  = ['green', 'red', 'blue'], title = 'Epoch photometry', fontsize = fontsize, show_legend = show_legend, show_grid = show_grid, figsize = figsize)
        if 'wavelength' in dl_out.keys():
            if len(dl_out) == 343:  title = key
            if len(dl_out) == 2401: title = key
            plot_sampled_spec(dl_out, color = 'blue', title = title, fontsize = fontsize, show_legend = False, show_grid = show_grid, linewidth = linewidth, legend = '', figsize = figsize)
    return dl_out    


def plot_e_phot(inp_table, colours  = ['green', 'red', 'blue'], title = 'Epoch photometry', fontsize = 12, show_legend = True, show_grid = True, figsize = [15,5]):
    ""
    "Epoch photometry plotter. 'inp_table' MUST be an Astropy-table object."
    ""       
    fig      = plt.figure(figsize=figsize)
    xlabel   = f'JD date [{inp_table["time"].unit}]'
    ylabel   = f'magnitude [{inp_table["mag"].unit}]'
    gbands   = ['G', 'RP', 'BP']  
    colours  = iter(colours)

    plt.gca().invert_yaxis()
    for band in gbands:
        phot_set = inp_table[inp_table['band'] == band]
        plt.plot(phot_set['time'], phot_set['mag'], 'o', label = band, color = next(colours))
    make_canvas(title = title, xlabel = xlabel, ylabel = ylabel, fontsize= fontsize, show_legend=show_legend, show_grid = show_grid)
    plt.show()

    
def plot_sampled_spec(inp_table, color = 'blue', title = '', fontsize = 14, show_legend = True, show_grid = True, linewidth = 2, legend = '', figsize = [12,4], show_plot = True):
    ""
    "RVS & XP sampled spectrum plotter. 'inp_table' MUST be an Astropy-table object."
    ""       
    if show_plot:
        fig      = plt.figure(figsize=figsize)
    xlabel   = f'Wavelength [{inp_table["wavelength"].unit}]'
    ylabel   = f'Flux [{inp_table["flux"].unit}]'
    plt.plot(inp_table['wavelength'], inp_table['flux'], '-', linewidth = linewidth, label = legend)
    make_canvas(title = title, xlabel = xlabel, ylabel = ylabel, fontsize= fontsize, show_legend=show_legend, show_grid = show_grid)
    if show_plot:
        plt.show()


def make_canvas(title = '', xlabel = '', ylabel = '', show_grid = False, show_legend = False, fontsize = 12):
    ""
    "Create generic canvas for plots"
    ""
    plt.title(title,    fontsize = fontsize)
    plt.xlabel(xlabel,  fontsize = fontsize)
    plt.ylabel(ylabel , fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    if show_grid:
        plt.grid()
    if show_legend:
        plt.legend(fontsize = fontsize*0.75)

# %%
Gaia.login()

# %%
query = """SELECT gaia3.source_id,gaia3.ra,gaia3.dec,gaia3.parallax,gaia3.pmra,gaia3.pmdec,gaia3.astrometric_params_solved,gaia3.ruwe,gaia3.bp_rp,gaia3.radial_velocity,gaia3.in_qso_candidates,gaia3.in_galaxy_candidates,gaia3.non_single_star,gaia3.has_xp_continuous,gaia3.has_xp_sampled,gaia3.has_rvs,gaia3.has_epoch_photometry,gaia3.has_epoch_rv,gaia3.has_mcmc_gspphot,gaia3.has_mcmc_msc,gaia3.teff_gspphot , DISTANCE(
            POINT(gaia2.ra, gaia2.dec),
            POINT(gaia3.ra, gaia3.dec)) AS ang_sep
            FROM user_abhatnag.dr2_sources AS gaia2
            JOIN gaiadr3.gaia_source_lite AS gaia3 
            ON 1 = CONTAINS(
            POINT(gaia2.ra, gaia2.dec),
            CIRCLE(gaia3.ra, gaia3.dec, 0.00028))"""

job = Gaia.launch_job_async(query)
data = job.get_results()

# %%
df_xp = pd.read_csv('../data/Gaia DR3/external/10.10510004-6361200912659/sources_xmatch.csv')
df_xp
# Out:
#       angDist    _RAJ2000   _DEJ2000  Cl   Sp    ALS  logFbol  Dist  \
# 0    1.401283    1.513333  63.679444   1    S   6036    -5.74   0.7
# 1    0.725315   35.468750  56.905000   1    S   7124    -6.10   1.2
# 2    1.776828   40.186250  61.282222   1    S   7374    -5.68   1.8
# 3    4.644194   40.186250  61.282222   1    S   7374    -5.68   1.8
# 4    4.769103   40.186250  61.282222   1    S   7374    -5.68   1.8
# ..        ...         ...        ...  ..  ...    ...      ...   ...
# 557  3.435575  253.581667 -41.819722   6  NaN   3810      NaN   0.2
# 558  3.903248  253.581667 -41.819722   6  NaN   3810      NaN   0.2
# 559  4.168521  253.581667 -41.819722   6  NaN   3810      NaN   0.2
# 560  0.253371  304.885000  38.731667   6  NaN  11163    -5.44   0.3
# 561  1.624404  309.181250  40.352222   6  NaN  19607    -4.02   1.2
#
#                  2XMM    CRpn  ...    B_AG  E(BP-RP)  b_E(BP-RP) B_E(BP-RP)  \
# 0    J000603.2+634046  0.3020  ...  1.2775    0.6823      0.6793     0.6963
# 1    J022152.5+565418     NaN  ...  1.1281    0.6060      0.5179     0.6140
# 2    J024044.7+611656     NaN  ...     NaN       NaN         NaN        NaN
# 3    J024044.7+611656     NaN  ...     NaN       NaN         NaN        NaN
# 4    J024044.7+611656     NaN  ...     NaN       NaN         NaN        NaN
# ..                ...     ...  ...     ...       ...         ...        ...
# 557  J165419.6-414911  0.0265  ...     NaN       NaN         NaN        NaN
# 558  J165419.6-414911  0.0265  ...     NaN       NaN         NaN        NaN
# 559  J165419.6-414911  0.0265  ...     NaN       NaN         NaN        NaN
# 560  J201932.4+384354  0.2360  ...     NaN       NaN         NaN        NaN
# 561  J203643.5+402108  0.3250  ...     NaN       NaN         NaN        NaN
#
#      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  RADEcorJ2000
# 0     OB    1.514121  63.679659   0.416877   0.486704       -0.4612
# 1      A   35.468384  56.905009   0.240032   0.324842        0.0663
# 2    NaN   40.187289  61.282221   3.570188   3.479530       -0.0027
# 3    NaN   40.188868  61.281915   2.671653   3.013517        0.0098
# 4    NaN   40.183711  61.281705   0.730981   1.214668        0.7862
# ..   ...         ...        ...        ...        ...           ...
# 557  NaN  253.580819 -41.818999   1.128849   0.804012        0.6843
# 558  NaN  253.582770 -41.820429  50.403885  41.432550        0.9989
# 559  NaN  253.580214 -41.819312  48.033623  25.178572       -0.2583
# 560  NaN  304.885095  38.731655   0.252124   0.297439       -0.0793
# 561  NaN  309.181801  40.352067   1.295429   1.348223       -0.0188
#
# [562 rows x 153 columns]

# %%
df_xp['source_id'] = 'Gaia DR3 ' + df_xp['gaia_dr3'].astype(str)
df_xp['source_id']
# Out:
# 0     Gaia DR3 2059863536357618816
# 1     Gaia DR3 2059073159271061632
# 2     Gaia DR3 2059219875373718016
# 3     Gaia DR3 1908368593700046720
# 4     Gaia DR3 1908095850396090880
# 5     Gaia DR3 1931240295282530688
# 6     Gaia DR3 1934565905639464448
# 7     Gaia DR3 1934938537001944960
# 8     Gaia DR3 2168287095193315328
# 9     Gaia DR3 1970219769209144320
# 10    Gaia DR3 2208114399949151616
# 11    Gaia DR3 2207626938340489728
# 12    Gaia DR3 2207645423880737152
# 13    Gaia DR3 2020566853331230720
# 14    Gaia DR3 2020088874998745600
# Name: source_id, dtype: object

# %%
table_xp = Table.from_pandas(df_xp)

# %% [markdown]
# # Download XP spectrums

# %%
dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
ids          = df_xp['DR3Name']
ids_chunks   = list(chunks(ids, dl_threshold))

print(f'* Input list contains {len(ids)} source_IDs')
print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')
# Out:
# * Input list contains 562 source_IDs
# * This list is split into 1 chunks of <= 5000 elements each

# %%
retrieval_type = 'XP_SAMPLED'        # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS' 
data_structure = 'INDIVIDUAL'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW' - but as explained above, we strongly recommend to use COMBINED for massive downloads.
data_release   = 'Gaia DR3'   # Options are: 'Gaia DR3' (default), 'Gaia DR2'
dl_key         = f'{retrieval_type}_{data_structure}.xml'


ii = 0
for chunk in ids_chunks:
    ii = ii + 1
    print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
    datalink  = Gaia.load_data(ids=chunk, data_release = data_release, retrieval_type=retrieval_type, format = 'votable', data_structure = data_structure)
    print(len(datalink))
    
    for dl_key in datalink.keys():
        if 'XP_SAMPLED' in dl_key: 
            product = datalink[dl_key][0]
            
            file_name = f"{dl_key.replace('.xml', '').replace(' ','_').replace('-','_')}.vot"

            print(f'Writing table as: {file_name}')
            product.to_table().write('../data/Gaia DR3/external/10.10510004-6361200912659/'+file_name, format = 'votable', overwrite = True)
            
            #dl_out = extract_dl_ind(datalink,dl_key, figsize=[20,7])
            #print(f'Showing {retrieval_type} for source_id = {dl_key.replace(".xml", "").replace("XP_SAMPLED-Gaia DR3 ","")}')
            #display(product.to_table())
# Out:
# Downloading Chunk #1; N_files = 562
# 278
# Writing table as: XP_SAMPLED_Gaia_DR3_168726523211215360.vot
# Writing table as: XP_SAMPLED_Gaia_DR3
vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5337650016801206272.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5337666406405518336.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5337667505909288704.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5338302164651661696.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5338310887667141888.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5339047221168787712.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350306426409875200.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350306529489092224.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350310927535609728.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350311339852481792.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350311374212228736.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350347520660979840.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350348860690746240.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350350303799853056.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350353567958779392.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350355251602278528.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350356007521809664.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350356419833915904.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357205782177664.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357313186767104.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357416266008960.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357519345171200.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357725503668096.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357931646616448.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350357966022158720.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350358069101053184.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350358240899842816.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350358240900286208.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350358550137500672.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350358683250920704.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350359306051691136.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350362948184049280.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350362982528878976.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363150021919360.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363807177529728.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363841537241088.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363841537246592.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363875896996480.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350363910256783488.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350370026290390912.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350382086559684480.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350383460949215232.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350383529668697472.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350387549760231808.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350389508263432320.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350391535488119552.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5350396620729366656.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5514368679541577856.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5515820034889610112.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5519249274219559296.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5534811177680971008.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5617678822143017088.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5854634126367279872.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5858915766471945984.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5858926619762114816.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5862407368673216000.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5864664975280537728.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5866059156028925312.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5866651998931097472.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5867262056094720256.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5870593301485825280.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5876932844981435904.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5876955006990526592.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5876955419331063936.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5922299347569528832.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5940106037148742272.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5940106213259136000.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5940106797374722688.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5941151986262863104.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966498478047526272.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966501501704611840.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966503597648760064.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966503769447442688.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966503902583913344.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966503941246144512.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966503941246146176.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966504044325373440.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966505762312172928.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966505796671904000.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509022176616448.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509095207261056.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509163926741888.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509267005564288.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509438804267264.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509541883497984.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509748041919616.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966509885480902656.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966510057279631488.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966510229078336768.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966514352246933376.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966515829715666304.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966520876291200256.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966522667303699072.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966523938614083712.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966524419650392832.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5966850768438120064.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5972197487366177664.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5972216591383770240.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5972270398744596480.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5972727348880921856.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_5972731918726009472.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6055100560991836544.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6055101523064612864.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6055662445790371968.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6057676201358478336.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6057680423278480512.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6057680496326765184.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6095347496917833472.vot
# Writing table as: XP_SAMPLED_Gaia_DR3_6705977119250947712.vot

# %% [markdown]
# # Download RVS spectrums

# %%
dl_threshold = 5000               # DataLink server threshold. It is not possible to download products for more than 5000 sources in one single call.
ids          = table_rvs['source_id']
ids_chunks   = list(chunks(ids, dl_threshold))
datalink_all = []


print(f'* Input list contains {len(ids)} source_IDs')
print(f'* This list is split into {len(ids_chunks)} chunks of <= {dl_threshold} elements each')
# Out:
# * Input list contains 924 source_IDs
# * This list is split into 1 chunks of <= 5000 elements each

# %%
retrieval_type = 'RVS'        # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS' 
data_structure = 'INDIVIDUAL'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW' - but as explained above, we strongly recommend to use COMBINED for massive downloads.
data_release   = 'Gaia DR3'   # Options are: 'Gaia DR3' (default), 'Gaia DR2'
dl_key         = f'{retrieval_type}_{data_structure}.xml'


ii = 0
for chunk in ids_chunks:
    ii = ii + 1
    print(f'Downloading Chunk #{ii}; N_files = {len(chunk)}')
    datalink  = Gaia.load_data(ids=chunk, data_release = data_release, retrieval_type=retrieval_type, format = 'votable', data_structure = data_structure)
    datalink_all.append(datalink)
    for dl_key in datalink.keys():
        if 'RVS' in dl_key:
            product = datalink[dl_key][0]
            file_name = f"{dl_key.replace('.xml', '').replace(' ','_').replace('-','_')}.vot"

            print(f'Writing table as: {file_name}')
            product.to_table().write('../datasets/Gaia DR3/RVS/'+file_name, format = 'votable', overwrite = True)
            
            #dl_out = extract_dl_ind(datalink,dl_key, figsize=[20,7])
            #print(f'Showing {retrieval_type} for source_id = {dl_key.replace(".xml", "").replace("RVS-Gaia DR3 ","")}')
            #display(product.to_table())
# Out:
# Downloading Chunk #1; N_files = 924
# Writing table as: RVS_Gaia_DR3_1101876819022885504.vot
# Writing table as: RVS_Gaia_DR3_1202908537318924672.vot
# Writing table as: RVS_Gaia_DR3_1264373951729187840.vot
# Writing table as: RVS_Gaia_DR3_128904067476795392.vot
# Writing table as: RVS_Gaia_DR3_1398436236272992256.vot
# Writing table as: RVS_Gaia_DR3_176895585371267456.vot
# Writing table as: RVS_Gaia_DR3_1803832633067414144.vot
# Writing table as: RVS_Gaia_DR3_1804853082938044416.vot
# Writing table as: RVS_Gaia_DR3_1808075236135604736.vot
# Writing table as: RVS_Gaia_DR3_1815850192083365120.vot
# Writing table as: RVS_Gaia_DR3_1820154058573970944.vot
# Writing table as: RVS_Gaia_DR3_1824230738491806208.vot
# Writing table as: RVS_Gaia_DR3_182635070426723840.vot
# Writing table as: RVS_Gaia_DR3_1828217086584470400.vot
# Writing table as: RVS_Gaia_DR3_1828386961117254272.vot
# Writing table as: RVS_Gaia_DR3_1834497634423975808.vot
# Writing table as: RVS_Gaia_DR3_1859834333694811008.vot
# Writing table as: RVS_Gaia_DR3_1861631279299654528.vot
# Writing table as: RVS_Gaia_DR3_1861857091480944128.vot
# Writing table as: RVS_Gaia_DR3_1873494185115620608.vot
# Writing table as: RVS_Gaia_DR3_188885003758866944.vot
# Writing table as: RVS_Gaia_DR3_188903145698556416.vot
# Writing table as: RVS_Gaia_DR3_1915667396702502400.vot
# Writing table as: RVS_Gaia_DR3_1925366772886281088.vot
# Writing table as: RVS_Gaia_DR3_1929775745794054656.vot
# Writing table as: RVS_Gaia_DR3_1941508050259084288.vot
# Writing table as: RVS_Gaia_DR3_194412313130613248.vot
# Writing table as: RVS_Gaia_DR3_194649640140781184.vot
# Writing table as: RVS_Gaia_DR3_195255952080715392.vot
# Writing table as: RVS_Gaia_DR3_1953356353201854592.vot
# Writing table as: RVS_Gaia_DR3_195706717491505280.vot
# Writing table as: RVS_Gaia_DR3_1971980323531421312.vot
# Writing table as: RVS_Gaia_DR3_1971997473351871616.vot
# Writing table as: RVS_Gaia_DR3_1972355948496193280.vot
# Writing table as: RVS_Gaia_DR3_1972937624504810368.vot
# Writing table as: RVS_Gaia_DR3_1978498610732122880.vot
# Writing table as: RVS_Gaia_DR3_1978522009714007168.vot
# Writing table as: RVS_Gaia_DR3_1979003389642223872.vot
# Writing table as: RVS_Gaia_DR3_1979365575645021056.vot
# Writing table as: RVS_Gaia_DR3_1980519616178408320.vot
# Writing table as: RVS_Gaia_DR3_1981285254232053504.vot
# Writing table as: RVS_Gaia_DR3_1992920144525656320.vot
# Writing table as: RVS_Gaia_DR3_199705877501647616.vot
# Writing table as: RVS_Gaia_DR3_1998883826872353664.vot
# Writing table as: RVS_Gaia_DR3_1999119195385417344.vot
# Writing table as: RVS_Gaia_DR3_1999245158183717760.vot
# Writing table as: RVS_Gaia_DR3_1999571713139659392.vot
# Writing table as: RVS_Gaia_DR3_2003644476012801280.vot
# Writing table as: RVS_Gaia_DR3_2005045975386695296.vot
# Writing table as: RVS_Gaia_DR3_2005046078465907456.vot
# Writing table as: RVS_Gaia_DR3_2005652321689619840.vot
# Writing table as: RVS_Gaia_DR3_2005663729122906752.vot
# Writing table as: RVS_Gaia_DR3_2005696095997969408.vot
# Writing table as: RVS_Gaia_DR3_2005714444098402432.vot
# Writing table as: RVS_Gaia_DR3_200576488852248448.vot
# Writing table as: RVS_Gaia_DR3_2005826834800990848.vot
# Writing table as: RVS_Gaia_DR3_2005840097660717824.vot
# Writing table as: RVS_Gaia_DR3_2005858308321933824.vot
# Writing table as: RVS_Gaia_DR3_2005881810384205696.vot
# Writing table as: RVS_Gaia_DR3_2005897787663468160.vot
# Writing table as: RVS_Gaia_DR3_2005914314697734016.vot
# Writing table as: RVS_Gaia_DR3_2005918815823435008.vot
# Writing table as: RVS_Gaia_DR3_2006073572061397888.vot
# Writing table as: RVS_Gaia_DR3_2006078794757784320.vot
# Writing table as: RVS_Gaia_DR3_2006085701065394304.vot
# Writing table as: RVS_Gaia_DR3_2006143700305731584.vot
# Writing table as: RVS_Gaia_DR3_2006177063612197120.vot
# Writing table as: RVS_Gaia_DR3_2006238292662534016.vot
# Writing table as: RVS_Gaia_DR3_2006938372331595136.vot
# Writing table as: RVS_Gaia_DR3_200760038574088192.vot
# Writing table as: RVS_Gaia_DR3_2007614640707006976.vot
# Writing table as: RVS_Gaia_DR3_2008194358202221440.vot
# Writing table as: RVS_Gaia_DR3_2008227618429670912.vot
# Writing table as: RVS_Gaia_DR3_2009127495673740288.vot
# Writing table as: RVS_Gaia_DR3_2009849535523502976.vot
# Writing table as: RVS_Gaia_DR3_201131531765285504.vot
# Writing table as: RVS_Gaia_DR3_2011405859867011328.vot
# Writing table as: RVS_Gaia_DR3_2011918575888325248.vot
# Writing table as: RVS_Gaia_DR3_201197403683901568.vot
# Writing table as: RVS_Gaia_DR3_2012120920380249088.vot
# Writing table as: RVS_Gaia_DR3_2012240835867141376.vot
# Writing table as: RVS_Gaia_DR3_2012306359890431360.vot
# Writing table as: RVS_Gaia_DR3_2013362509531379456.vot
# Writing table as: RVS_Gaia_DR3_2013590108435796736.vot
# Writing table as: RVS_Gaia_DR3_2013876290699543808.vot
# Writing table as: RVS_Gaia_DR3_2013894913678836992.vot
# Writing table as: RVS_Gaia_DR3_2014195183429293440.vot
# Writing table as: RVS_Gaia_DR3_2014377526259898240.vot
# Writing table as: RVS_Gaia_DR3_4045424409101675648.vot
# Writing table as: RVS_Gaia_DR3_4053274303633039616.vot
# Writing table as: RVS_Gaia_DR3_4053533955793502464.vot
# Writing table as: RVS_Gaia_DR3_4053560004824497408.vot
# Writing table as: RVS_Gaia_DR3_4053632778755757056.vot
# Writing table as: RVS_Gaia_DR3_4053685860201675264.vot
# Writing table as: RVS_Gaia_DR3_4053719502739476096.vot
# Writing table as: RVS_Gaia_DR3_4054618834489095552.vot
# Writing table as: RVS_Gaia_DR3_4055003629187758592.vot
# Writing table as: RVS_Gaia_DR3_4056340704108946176.vot
# Writing table as: RVS_Gaia_DR3_4058634384075414528.vot
# Writing table as: RVS_Gaia_DR3_4058743098293883264.vot
# Writing table as: RVS_Gaia_DR3_4064074320934601344.vot
# Writing table as: RVS_Gaia_DR3_4064483893347134848.vot
# Writing table as: RVS_Gaia_DR3_4065976239862518144.vot
# Writing table as: RVS_Gaia_DR3_4066557396150859520.vot
# Writing table as: RVS_Gaia_DR3_4067518953423901568.vot
# Writing table as: RVS_Gaia_DR3_4067774628567920128.vot
# Writing table as: RVS_Gaia_DR3_4069168500057468928.vot
# Writing table as: RVS_Gaia_DR3_4069498594063996544.vot
# Writing table as: RVS_Gaia_DR3_4069777663860987008.vot
# Writing table as: RVS_Gaia_DR3_4088793064632541568.vot
# Writing table as: RVS_Gaia_DR3_4092909253894197504.vot
# Writing table as: RVS_Gaia_DR3_4093416408010168832.vot
# Writing table as: RVS_Gaia_DR3_4094245611500966912.vot
# Writing table as: RVS_Gaia_DR3_4094814162127907200.vot
# Writing table as: RVS_Gaia_DR3_4094860616496202624.vot
# Writing table as: RVS_Gaia_DR3_4095103054465255296.vot
# Writing table as: RVS_Gaia_DR3_4097715910719248000.vot
# Writing table as: RVS_Gaia_DR3_4097788925166221824.vot
# Writing table as: RVS_Gaia_DR3_4098199176129544832.vot
# Writing table as: RVS_Gaia_DR3_4098262917752306944.vot
# Writing table as: RVS_Gaia_DR3_4103544731146383488.vot
# Writing table as: RVS_Gaia_DR3_4103562804371355392.vot
# Writing table as: RVS_Gaia_DR3_4104103695429651584.vot
# Writing table as: RVS_Gaia_DR3_4104315072127225472.vot
# Writing table as: RVS_Gaia_DR3_4104472203500910976.vot
# Writing table as: RVS_Gaia_DR3_4104673242416245248.vot
# Writing table as: RVS_Gaia_DR3_4104933311266741760.vot
# Writing table as: RVS_Gaia_DR3_4104948253380180096.vot
# Writing table as: RVS_Gaia_DR3_4106462933725240192.vot
# Writing table as: RVS_Gaia_DR3_4106703628073441536.vot
# Writing table as: RVS_Gaia_DR3_4107165212423307008.vot
# Writing table as: RVS_Gaia_DR3_4109650937702406272.vot
# Writing table as: RVS_Gaia_DR3_4130276573181045376.vot
# Writing table as: RVS_Gaia_DR3_4144012840695602944.vot
# Writing table as: RVS_Gaia_DR3_4145969730898007936.vot
# Writing table as: RVS_Gaia_DR3_4146023366437650816.vot
# Writing table as: RVS_Gaia_DR3_4146315870848249088.vot
# Writing table as: RVS_Gaia_DR3_4146410669375970688.vot
# Writing table as: RVS_Gaia_DR3_4146517940483579392.vot
# Writing table as: RVS_Gaia_DR3_4146596035854624256.vot
# Writing table as: RVS_Gaia_DR3_4146598475396221952.vot
# Writing table as: RVS_Gaia_DR3_4146611879992060800.vot
# Writing table as: RVS_Gaia_DR3_4146617789867126528.vot
# Writing table as: RVS_Gaia_DR3_4150502604989797632.vot
# Writing table as: RVS_Gaia_DR3_4152354251273533568.vot
# Writing table as: RVS_Gaia_DR3_4152516910278032896.vot
# Writing table as: RVS_Gaia_DR3_4152548693039054720.vot
# Writing table as: RVS_Gaia_DR3_4152595594079497344.vot
# Writing table as: RVS_Gaia_DR3_4152605901998464640.vot
# Writing table as: RVS_Gaia_DR3_4153256434939776000.vot
# Writing table as: RVS_Gaia_DR3_4153563404839400832.vot
# Writing table as: RVS_Gaia_DR3_4153566084899062528.vot
# Writing table as: RVS_Gaia_DR3_4153680056178134784.vot
# Writing table as: RVS_Gaia_DR3_4154423703966989568.vot
# Writing table as: RVS_Gaia_DR3_4154644396590328960.vot
# Writing table as: RVS_Gaia_DR3_4155176968192590848.vot
# Writing table as: RVS_Gaia_DR3_4155601109147104512.vot
# Writing table as: RVS_Gaia_DR3_4156126125925736704.vot
# Writing table as: RVS_Gaia_DR3_4156506797459266816.vot
# Writing table as: RVS_Gaia_DR3_416562487127705984.vot
# Writing table as: RVS_Gaia_DR3_4168517278355561088.vot
# Writing table as: RVS_Gaia_DR3_418030923572427520.vot
# Writing table as: RVS_Gaia_DR3_4184198788077655936.vot
# Writing table as: RVS_Gaia_DR3_4190636669164572928.vot
# Writing table as: RVS_Gaia_DR3_4198671006791595392.vot
# Writing table as: RVS_Gaia_DR3_4199197050081918592.vot
# Writing table as: RVS_Gaia_DR3_4228943688634018816.vot
# Writing table as: RVS_Gaia_DR3_4231133434759619200.vot
# Writing table as: RVS_Gaia_DR3_4238245591376160768.vot
# Writing table as: RVS_Gaia_DR3_4238268646760701568.vot
# Writing table as: RVS_Gaia_DR3_425106830652021632.vot
# Writing table as: RVS_Gaia_DR3_4252639641720957696.vot
# Writing table as: RVS_Gaia_DR3_4252787045060709888.vot
# Writing table as: RVS_Gaia_DR3_4253146173068393216.vot
# Writing table as: RVS_Gaia_DR3_425352708938778368.vot
# Writing table as: RVS_Gaia_DR3_4255271803843844608.vot
# Writing table as: RVS_Gaia_DR3_4255348456083989632.vot
# Writing table as: RVS_Gaia_DR3_4255640689992990464.vot
# Writing table as: RVS_Gaia_DR3_4256149763841175168.vot
# Writing table as: RVS_Gaia_DR3_4256895919950642176.vot
# Writing table as: RVS_Gaia_DR3_426021212000338176.vot
# Writing table as: RVS_Gaia_DR3_4261175872023667456.vot
# Writing table as: RVS_Gaia_DR3_4264967400467007232.vot
# Writing table as: RVS_Gaia_DR3_4266017056073768576.vot
# Writing table as: RVS_Gaia_DR3_426670370548306432.vot
# Writing table as: RVS_Gaia_DR3_4267244076722314240.vot
# Writing table as: RVS_Gaia_DR3_461123533039697024.vot
# Writing table as: RVS_Gaia_DR3_461366799989028608.vot
# Writing table as: RVS_Gaia_DR3_461456474604104448.vot
# Writing table as: RVS_Gaia_DR3_461516436649149184.vot
# Writing table as: RVS_Gaia_DR3_462250738616785152.vot
# Writing table as: RVS_Gaia_DR3_462759949937775360.vot
# Writing table as: RVS_Gaia_DR3_463235282558866048.vot
# Writing table as: RVS_Gaia_DR3_464779237403388928.vot
# Writing table as: RVS_Gaia_DR3_464841565971672064.vot
# Writing table as: RVS_Gaia_DR3_465143278831063936.vot
# Writing table as: RVS_Gaia_DR3_4654833539071572736.vot
# Writing table as: RVS_Gaia_DR3_466201245234867968.vot
# Writing table as: RVS_Gaia_DR3_467515887487537536.vot
# Writing table as: RVS_Gaia_DR3_468306779942552192.vot
# Writing table as: RVS_Gaia_DR3_470276726823694976.vot
# Writing table as: RVS_Gaia_DR3_493606886093407616.vot
# Writing table as: RVS_Gaia_DR3_4939205900704478592.vot
# Writing table as: RVS_Gaia_DR3_49415527182759296.vot
# Writing table as: RVS_Gaia_DR3_4998644812107991296.vot
# Writing table as: RVS_Gaia_DR3_504957934907964672.vot
# Writing table as: RVS_Gaia_DR3_505105991020283648.vot
# Writing table as: RVS_Gaia_DR3_506778691804372736.vot
# Writing table as: RVS_Gaia_DR3_508065601442412544.vot
# Writing table as: RVS_Gaia_DR3_508201528571171712.vot
# Writing table as: RVS_Gaia_DR3_508478639859504512.vot
# Writing table as: RVS_Gaia_DR3_509148276799636480.vot
# Writing table as: RVS_Gaia_DR3_509749125548519424.vot
# Writing table as: RVS_Gaia_DR3_511260782234988672.vot
# Writing table as: RVS_Gaia_DR3_511585580537772416.vot
# Writing table as: RVS_Gaia_DR3_511593861234713856.vot
# Writing table as: RVS_Gaia_DR3_515067630783462016.vot
# Writing table as: RVS_Gaia_DR3_517287858295092608.vot
# Writing table as: RVS_Gaia_DR3_518166466865478784.vot
# Writing table as: RVS_Gaia_DR3_5201142418353127424.vot
# Writing table as: RVS_Gaia_DR3_521376186122882304.vot
# Writing table as: RVS_Gaia_DR3_522682955701497472.vot
# Writing table as: RVS_Gaia_DR3_522867398773815424.vot
# Writing table as: RVS_Gaia_DR3_5235050120023783936.vot
# Writing table as: RVS_Gaia_DR3_5236423233930713088.vot
# Writing table as: RVS_Gaia_DR3_5239895633422585856.vot
# Writing table as: RVS_Gaia_DR3_524063839226112896.vot
# Writing table as: RVS_Gaia_DR3_5241942236892363776.vot
# Writing table as: RVS_Gaia_DR3_524403141639508480.vot
# Writing table as: RVS_Gaia_DR3_5253665436021918208.vot
# Writing table as: RVS_Gaia_DR3_5254196981175369344.vot
# Writing table as: RVS_Gaia_DR3_5254245222251298688.vot
# Writing table as: RVS_Gaia_DR3_5254269617668289664.vot
# Writing table as: RVS_Gaia_DR3_5254495258056165760.vot
# Writing table as: RVS_Gaia_DR3_5254707841763291648.vot
# Writing table as: RVS_Gaia_DR3_5255208634949562112.vot
# Writing table as: RVS_Gaia_DR3_5255431904519734144.vot
# Writing table as: RVS_Gaia_DR3_5255458533311654016.vot
# Writing table as: RVS_Gaia_DR3_5257924394292909696.vot
# Writing table as: RVS_Gaia_DR3_5258262116155575296.vot
# Writing table as: RVS_Gaia_DR3_5258437350816823936.vot
# Writing table as: RVS_Gaia_DR3_525862296645549568.vot
# Writing table as: RVS_Gaia_DR3_5290671733195996416.vot
# Writing table as: RVS_Gaia_DR3_5290739387520374912.vot
# Writing table as: RVS_Gaia_DR3_5290816009737675392.vot
# Writing table as: RVS_Gaia_DR3_5304709816633460736.vot
# Writing table as: RVS_Gaia_DR3_5307854351179113216.vot
# Writing table as: RVS_Gaia_DR3_5307873042876416384.vot
# Writing table as: RVS_Gaia_DR3_5308770897197800704.vot
# Writing table as: RVS_Gaia_DR3_5314755642051435904.vot
# Writing table as: RVS_Gaia_DR3_5318327165064125696.vot
# Writing table as: RVS_Gaia_DR3_5318422410259376384.vot
# Writing table as: RVS_Gaia_DR3_5324415057863136384.vot
# Writing table as: RVS_Gaia_DR3_5329798026283063680.vot
# Writing table as: RVS_Gaia_DR3_5330299918969106560.vot
# Writing table as: RVS_Gaia_DR3_5332987365945232768.vot
# Writing table as: RVS_Gaia_DR3_5333632774931920128.vot
# Writing table as: RVS_Gaia_DR3_5333960742947280128.vot
# Writing table as: RVS_Gaia_DR3_5333970771675296896.vot
# Writing table as: RVS_Gaia_DR3_5334266785143216128.vot
# Writing table as: RVS_Gaia_DR3_5334533622900362496.vot
# Writing table as: RVS_Gaia_DR3_5334549767626240768.vot
# Writing table as: RVS_Gaia_DR3_5334608080460780672.vot
# Writing table as: RVS_Gaia_DR3_5334646460294760832.vot
# Writing table as: RVS_Gaia_DR3_5334865606695647872.vot
# Writing table as: RVS_Gaia_DR3_5335188931833682176.vot
# Writing table as: RVS_Gaia_DR3_5335306854457670784.vot
# Writing table as: RVS_Gaia_DR3_5335482673237138688.vot
# Writing table as: RVS_Gaia_DR3_5335490301100151168.vot
# Writing table as: RVS_Gaia_DR3_5335714395314185728.vot
# Writing table as: RVS_Gaia_DR3_5336288237304556288.vot
# Writing table as: RVS_Gaia_DR3_5337133555562213248.vot
# Writing table as: RVS_Gaia_DR3_5337205401776883328.vot
# Writing table as: RVS_Gaia_DR3_5338061955708183680.vot
# Writing table as: RVS_Gaia_DR3_5338262272989958784.vot
# Writing table as: RVS_Gaia_DR3_5338265842051793536.vot
# Writing table as: RVS_Gaia_DR3_5338321882787007488.vot
# Writing table as: RVS_Gaia_DR3_5338445960147929088.vot
# Writing table as: RVS_Gaia_DR3_5338704070495410304.vot
# Writing table as: RVS_Gaia_DR3_5338763478484498944.vot
# Writing table as: RVS_Gaia_DR3_5338806393798360704.vot
# Writing table as: RVS_Gaia_DR3_5339121124661225344.vot
# Writing table as: RVS_Gaia_DR3_5340247097605060992.vot
# Writing table as: RVS_Gaia_DR3_5340628215834621056.vot
# Writing table as: RVS_Gaia_DR3_5341320938187133184.vot
# Writing table as: RVS_Gaia_DR3_5341333002804086656.vot
# Writing table as: RVS_Gaia_DR3_5341356706679108224.vot
# Writing table as: RVS_Gaia_DR3_5345802895478324224.vot
# Writing table as: RVS_Gaia_DR3_5350279213497594496.vot
# Writing table as: RVS_Gaia_DR3_5350301306809073280.vot
# Writing table as: RVS_Gaia_DR3_5350363807177527680.vot
# Writing table as: RVS_Gaia_DR3_5350363875896996480.vot
# Writing table as: RVS_Gaia_DR3_5350363905936139904.vot
# Writing table as: RVS_Gaia_DR3_5350363910256783488.vot
# Writing table as: RVS_Gaia_DR3_5350533299441651584.vot
# Writing table as: RVS_Gaia_DR3_5350622982675209984.vot
# Writing table as: RVS_Gaia_DR3_5350814435144204032.vot
# Writing table as: RVS_Gaia_DR3_5351070376514879616.vot
# Writing table as: RVS_Gaia_DR3_5351397794790499072.vot
# Writing table as: RVS_Gaia_DR3_5351548771461692160.vot
# Writing table as: RVS_Gaia_DR3_5351643123306248064.vot
# Writing table as: RVS_Gaia_DR3_5351834335244524288.vot
# Writing table as: RVS_Gaia_DR3_5351887524120313984.vot
# Writing table as: RVS_Gaia_DR3_5352546578279554944.vot
# Writing table as: RVS_Gaia_DR3_5356700185285121152.vot
# Writing table as: RVS_Gaia_DR3_5358308981271706368.vot
# Writing table as: RVS_Gaia_DR3_539042726640996352.vot
# Writing table as: RVS_Gaia_DR3_5390847825284977408.vot
# Writing table as: RVS_Gaia_DR3_5404489397354905344.vot
# Writing table as: RVS_Gaia_DR3_5405303375237889408.vot
# Writing table as: RVS_Gaia_DR3_5422651164763676800.vot
# Writing table as: RVS_Gaia_DR3_5423801425726635264.vot
# Writing table as: RVS_Gaia_DR3_54819798632949632.vot
# Writing table as: RVS_Gaia_DR3_5521485509081994112.vot
# Writing table as: RVS_Gaia_DR3_5521929505614032256.vot
# Writing table as: RVS_Gaia_DR3_5524471473410215808.vot
# Writing table as: RVS_Gaia_DR3_5525751408022984320.vot
# Writing table as: RVS_Gaia_DR3_5541174360711461888.vot
# Writing table as: RVS_Gaia_DR3_5546374363522452224.vot
# Writing table as: RVS_Gaia_DR3_5546410716127097600.vot
# Writing table as: RVS_Gaia_DR3_5546559699951048704.vot
# Writing table as: RVS_Gaia_DR3_5546711192039738752.vot
# Writing table as: RVS_Gaia_DR3_5556897647560453376.vot
# Writing table as: RVS_Gaia_DR3_5591424825237198336.vot
# Writing table as: RVS_Gaia_DR3_5591815697316522112.vot
# Writing table as: RVS_Gaia_DR3_5594074132867556992.vot
# Writing table as: RVS_Gaia_DR3_5595326133012539776.vot
# Writing table as: RVS_Gaia_DR3_5595520020713436544.vot
# Writing table as: RVS_Gaia_DR3_5595765147395308160.vot
# Writing table as: RVS_Gaia_DR3_5596083868330026624.vot
# Writing table as: RVS_Gaia_DR3_5597774745412826368.vot
# Writing table as: RVS_Gaia_DR3_5600361964992835712.vot
# Writing table as: RVS_Gaia_DR3_5600362411668920192.vot
# Writing table as: RVS_Gaia_DR3_5600389865098404352.vot
# Writing table as: RVS_Gaia_DR3_5600408007041463808.vot
# Writing table as: RVS_Gaia_DR3_5600442293749292160.vot
# Writing table as: RVS_Gaia_DR3_5600488821147725184.vot
# Writing table as: RVS_Gaia_DR3_5600499949390735488.vot
# Writing table as: RVS_Gaia_DR3_5600665670716998656.vot
# Writing table as: RVS_Gaia_DR3_5600677937143320704.vot
# Writing table as: RVS_Gaia_DR3_5600682747506753536.vot
# Writing table as: RVS_Gaia_DR3_5600697453476253312.vot
# Writing table as: RVS_Gaia_DR3_5600752085461089280.vot
# Writing table as: RVS_Gaia_DR3_5600759988203334528.vot
# Writing table as: RVS_Gaia_DR3_5600807438999376256.vot
# Writing table as: RVS_Gaia_DR3_5600860765315758080.vot
# Writing table as: RVS_Gaia_DR3_5600864682327599104.vot
# Writing table as: RVS_Gaia_DR3_5600901756484522112.vot
# Writing table as: RVS_Gaia_DR3_5601082316904612480.vot
# Writing table as: RVS_Gaia_DR3_5601138147174078080.vot
# Writing table as: RVS_Gaia_DR3_5601153579004714880.vot
# Writing table as: RVS_Gaia_DR3_5601155949828792832.vot
# Writing table as: RVS_Gaia_DR3_5601620768367314688.vot
# Writing table as: RVS_Gaia_DR3_5601626850040626816.vot
# Writing table as: RVS_Gaia_DR3_5601628842905301760.vot
# Writing table as: RVS_Gaia_DR3_5601844239798060032.vot
# Writing table as: RVS_Gaia_DR3_5601927394671610752.vot
# Writing table as: RVS_Gaia_DR3_5601958971272466176.vot
# Writing table as: RVS_Gaia_DR3_5601990650952435840.vot
# Writing table as: RVS_Gaia_DR3_5602008002622593280.vot
# Writing table as: RVS_Gaia_DR3_5602010957557214464.vot
# Writing table as: RVS_Gaia_DR3_5602081493789681920.vot
# Writing table as: RVS_Gaia_DR3_5602297685261430784.vot
# Writing table as: RVS_Gaia_DR3_5608811020345672064.vot
# Writing table as: RVS_Gaia_DR3_5610373361952127488.vot
# Writing table as: RVS_Gaia_DR3_5610429024727430144.vot
# Writing table as: RVS_Gaia_DR3_5616353159022994176.vot
# Writing table as: RVS_Gaia_DR3_5616537086705980672.vot
# Writing table as: RVS_Gaia_DR3_5616608829834868992.vot
# Writing table as: RVS_Gaia_DR3_5618484867244232192.vot
# Writing table as: RVS_Gaia_DR3_5619872730105389568.vot
# Writing table as: RVS_Gaia_DR3_5620273364653464192.vot
# Writing table as: RVS_Gaia_DR3_5620284256691515648.vot
# Writing table as: RVS_Gaia_DR3_5620363348500620544.vot
# Writing table as: RVS_Gaia_DR3_5743188422345872512.vot
# Writing table as: RVS_Gaia_DR3_5759268882981466112.vot
# Writing table as: RVS_Gaia_DR3_5817497197735550848.vot
# Writing table as: RVS_Gaia_DR3_5818874988883127552.vot
# Writing table as: RVS_Gaia_DR3_582157738659724800.vot
# Writing table as: RVS_Gaia_DR3_5834395248449591680.vot
# Writing table as: RVS_Gaia_DR3_5838611772356846080.vot
# Writing table as: RVS_Gaia_DR3_5844118332764146432.vot
# Writing table as: RVS_Gaia_DR3_5844368437302129920.vot
# Writing table as: RVS_Gaia_DR3_5848217479586889344.vot
# Writing table as: RVS_Gaia_DR3_5849528475404497152.vot
# Writing table as: RVS_Gaia_DR3_5854821837930542848.vot
# Writing table as: RVS_Gaia_DR3_5856122010437319424.vot
# Writing table as: RVS_Gaia_DR3_5856805185143238272.vot
# Writing table as: RVS_Gaia_DR3_5861994192847013376.vot
# Writing table as: RVS_Gaia_DR3_5862431626641632768.vot
# Writing table as: RVS_Gaia_DR3_5862536217691724288.vot
# Writing table as: RVS_Gaia_DR3_5862559273077474688.vot
# Writing table as: RVS_Gaia_DR3_5862733545640323584.vot
# Writing table as: RVS_Gaia_DR3_5862896788783668096.vot
# Writing table as: RVS_Gaia_DR3_5863065769955067648.vot
# Writing table as: RVS_Gaia_DR3_5863155655040550272.vot
# Writing table as: RVS_Gaia_DR3_5863584773814009984.vot
# Writing table as: RVS_Gaia_DR3_5863660674479813888.vot
# Writing table as: RVS_Gaia_DR3_5864246508089181696.vot
# Writing table as: RVS_Gaia_DR3_5864664975280541056.vot
# Writing table as: RVS_Gaia_DR3_5864671709789425920.vot
# Writing table as: RVS_Gaia_DR3_5864845054747180416.vot
# Writing table as: RVS_Gaia_DR3_5864942361543329280.vot
# Writing table as: RVS_Gaia_DR3_5865047948975423488.vot
# Writing table as: RVS_Gaia_DR3_5866255624995706496.vot
# Writing table as: RVS_Gaia_DR3_5868668743811491072.vot
# Writing table as: RVS_Gaia_DR3_5908044209357677440.vot
# Writing table as: RVS_Gaia_DR3_5912237884143834240.vot
# Writing table as: RVS_Gaia_DR3_5912245962988846592.vot
# Writing table as: RVS_Gaia_DR3_5912255240118270976.vot
# Writing table as: RVS_Gaia_DR3_5912389792852926336.vot
# Writing table as: RVS_Gaia_DR3_5912391918851025024.vot
# Writing table as: RVS_Gaia_DR3_5912398657665539840.vot
# Writing table as: RVS_Gaia_DR3_5912404086504293376.vot
# Writing table as: RVS_Gaia_DR3_5912412053657649920.vot
# Writing table as: RVS_Gaia_DR3_5912412294175812480.vot
# Writing table as: RVS_Gaia_DR3_5912417860453458176.vot
# Writing table as: RVS_Gaia_DR3_5912426690906184064.vot
# Writing table as: RVS_Gaia_DR3_5912437793408452608.vot
# Writing table as: RVS_Gaia_DR3_5912439545755208192.vot
# Writing table as: RVS_Gaia_DR3_5912443114866146944.vot
# Writing table as: RVS_Gaia_DR3_5912444149960060672.vot
# Writing table as: RVS_Gaia_DR3_5912444562276952960.vot
# Writing table as: RVS_Gaia_DR3_5912447104897714816.vot
# Writing table as: RVS_Gaia_DR3_5912455179436786816.vot
# Writing table as: RVS_Gaia_DR3_5912455282516011008.vot
# Writing table as: RVS_Gaia_DR3_5912458164426544512.vot
# Writing table as: RVS_Gaia_DR3_5912461604707886976.vot
# Writing table as: RVS_Gaia_DR3_5912553104690849664.vot
# Writing table as: RVS_Gaia_DR3_5912564649563675008.vot
# Writing table as: RVS_Gaia_DR3_5912568154256982912.vot
# Writing table as: RVS_Gaia_DR3_5912579561690370176.vot
# Writing table as: RVS_Gaia_DR3_5912586674156213376.vot
# Writing table as: RVS_Gaia_DR3_5912587704948449664.vot
# Writing table as: RVS_Gaia_DR3_5912603269911040768.vot
# Writing table as: RVS_Gaia_DR3_5912754555840211456.vot
# Writing table as: RVS_Gaia_DR3_5912762149342489344.vot
# Writing table as: RVS_Gaia_DR3_5912768368455408000.vot
# Writing table as: RVS_Gaia_DR3_5912770155162102016.vot
# Writing table as: RVS_Gaia_DR3_5912783246222667648.vot
# Writing table as: RVS_Gaia_DR3_5912795473978465664.vot
# Writing table as: RVS_Gaia_DR3_5912881686871488640.vot
# Writing table as: RVS_Gaia_DR3_5912884401290752512.vot
# Writing table as: RVS_Gaia_DR3_5912900069331897216.vot
# Writing table as: RVS_Gaia_DR3_5912901375001820288.vot
# Writing table as: RVS_Gaia_DR3_5912911545484974336.vot
# Writing table as: RVS_Gaia_DR3_5912918898470680960.vot
# Writing table as: RVS_Gaia_DR3_5912928106879001728.vot
# Writing table as: RVS_Gaia_DR3_5912929339519159552.vot
# Writing table as: RVS_Gaia_DR3_5912934875747617920.vot
# Writing table as: RVS_Gaia_DR3_5912939205074802176.vot
# Writing table as: RVS_Gaia_DR3_5912939372568995584.vot
# Writing table as: RVS_Gaia_DR3_5912939583031933440.vot
# Writing table as: RVS_Gaia_DR3_5912945527265173248.vot
# Writing table as: RVS_Gaia_DR3_5912947451410556928.vot
# Writing table as: RVS_Gaia_DR3_5912956041345680640.vot
# Writing table as: RVS_Gaia_DR3_5912957828052109568.vot
# Writing table as: RVS_Gaia_DR3_5912959305520492544.vot
# Writing table as: RVS_Gaia_DR3_5912963325609913088.vot
# Writing table as: RVS_Gaia_DR3_5912964459481346560.vot
# Writing table as: RVS_Gaia_DR3_5912966860354001152.vot
# Writing table as: RVS_Gaia_DR3_5912968067253956992.vot
# Writing table as: RVS_Gaia_DR3_5939669810244259840.vot
# Writing table as: RVS_Gaia_DR3_5940516193714326016.vot
# Writing table as: RVS_Gaia_DR3_5940845428693993856.vot
# Writing table as: RVS_Gaia_DR3_6002277170537272832.vot
# Writing table as: RVS_Gaia_DR3_6002290364677358592.vot
# Writing table as: RVS_Gaia_DR3_6048976762246802944.vot
# Writing table as: RVS_Gaia_DR3_6135588797858442112.vot
# Writing table as: RVS_Gaia_DR3_6171076532076110976.vot
# Writing table as: RVS_Gaia_DR3_64679840952155264.vot
# Writing table as: RVS_Gaia_DR3_65287458566524928.vot
# Writing table as: RVS_Gaia_DR3_6692125884070450176.vot
# Writing table as: RVS_Gaia_DR3_6712993206016290432.vot
# Writing table as: RVS_Gaia_DR3_6734890976548361984.vot
# Writing table as: RVS_Gaia_DR3_710757924314671872.vot
# Writing table as: RVS_Gaia_DR3_8900825800310016.vot
# Writing table as: RVS_Gaia_DR3_945182530731075840.vot
# Writing table as: RVS_Gaia_DR3_970353341187851008.vot
# Writing table as: RVS_Gaia_DR3_976427971132363264.vot
# Writing table as: RVS_Gaia_DR3_977835346015315712.vot
