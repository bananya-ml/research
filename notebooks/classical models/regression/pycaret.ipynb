# %%
import pandas as pd
from pycaret.regression import setup, RegressionExperiment, compare_models
from pycaret.parallel import FugueBackend
from sklearn.decomposition import PCA
import numpy as np
import h5py
import polars as pl

# %%
datadir = '../../../data/APOGEE/'

training_set = datadir + 'training_data.h5'
normalization_data = datadir + 'mean_and_std.npy'

pca = PCA(n_components=1)

# %%
mean_and_std = np.load(normalization_data)
mean_labels = mean_and_std[0]
std_labels = mean_and_std[1]

# %%
def normalize(labels):
    # Normalize labels
    return (labels-mean_labels) / std_labels

# %%
# Define the number of output labels
num_labels = np.load(datadir+'mean_and_std.npy').shape[1]

# Load spectra and labels
with  h5py.File(training_set, 'r') as data_F:
    x_train = data_F['spectrum'][:]
    y_train = np.hstack((data_F['TEFF'][:], 
                         data_F['LOGG'][:], 
                         data_F['FE_H'][:]))

# Normalize labels
y_train = normalize(y_train)

# Transform into a single value
y_train = pca.fit_transform(y_train)

# Define the number of output labels
num_labels = y_train.shape[1]
num_fluxes = x_train.shape[1]

print('Each spectrum contains ' + str(num_fluxes) + ' wavelength bins')
print('Training set includes ' + str(x_train.shape[0]) + ' spectra.')
# Out:
# Each spectrum contains 7214 wavelength bins
# Training set includes 44784 spectra.

# %%
df_train = pd.concat([pd.DataFrame(x_train), pd.DataFrame(y_train, columns=['target'])], axis=1)

df_train
# Out:
#               0         1         2         3         4         5         6  \
# 0      1.036881  1.027561  1.017815  1.016619  1.016466  1.004510  0.988281
# 1      1.035711  1.023595  1.028486  1.033887  1.020416  1.021567  1.025008
# 2      1.011392  1.011521  1.008502  1.009408  1.007445  0.985910  0.955840
# 3      1.058238  1.067501  1.062629  1.050290  1.034646  1.026603  1.018828
# 4      1.002464  0.991758  0.982990  0.983890  0.988004  0.973203  0.937438
# ...         ...       ...       ...       ...       ...       ...       ...
# 44779  1.090833  1.085457  1.082925  1.083167  1.073133  1.063151  1.060633
# 44780  1.002617  0.996245  0.998153  1.003528  1.000306  0.978228  0.949339
# 44781  1.056679  1.070088  1.062519  1.057347  1.069799  1.057868  1.021001
# 44782  1.067051  1.066485  1.068391  1.072058  1.071626  1.056566  1.033489
# 44783  1.060152  1.057623  1.051992  1.048661  1.049523  1.045913  1.035114
#
#               7         8         9  ...      7205      7206      7207  \
# 0      0.990171  1.012946  1.038713  ...  0.947867  0.952879  0.954746
# 1      1.004612  1.001988  1.020844  ...  0.952132  0.963200  0.989394
# 2      0.954559  0.987229  1.022529  ...  0.935629  0.948573  0.939322
# 3      1.014678  1.039715  1.064574  ...  0.946117  0.961544  0.968247
# 4      0.924305  0.964944  1.020916  ...  0.955617  0.981374  0.969568
# ...         ...       ...       ...  ...       ...       ...       ...
# 44779  1.055826  1.055418  1.066160  ...  0.951984  0.980766  0.967344
# 44780  0.945489  0.979600  1.030298  ...  0.943019  0.950031  0.940917
# 44781  1.012670  1.039869  1.065146  ...  0.969660  0.965846  0.974367
# 44782  1.027605  1.045373  1.062937  ...  0.944424  0.944076  0.945529
# 44783  1.032995  1.042880  1.052988  ...  0.947502  0.949303  0.942968
#
#            7208      7209      7210      7211      7212      7213    target
# 0      0.937672  0.933191  0.944470  0.954676  0.955576  0.959755  0.134516
# 1      0.949660  0.917875  0.951611  0.936365  0.944244  0.936340  1.622526
# 2      0.935014  0.922320  0.931384  0.945553  0.950321  0.961997 -0.750942
# 3      0.955850  0.948623  0.956111  0.945956  0.967346  1.005403  0.105903
# 4      0.947591  0.937702  0.954310  0.967761  0.987397  1.007436 -0.908189
# ...         ...       ...       ...       ...       ...       ...       ...
# 44779  0.974858  0.994483  0.970611  1.000234  0.991213  0.962700  0.606724
# 44780  0.936455  0.931839  0.931907  0.955119  0.968381  0.971754 -0.974801
# 44781  0.966351  0.963690  0.964948  0.971462  0.993141  0.979873 -0.938594
# 44782  0.944968  0.950801  0.961402  0.960059  0.959860  0.962276  0.432227
# 44783  0.939531  0.947309  0.952595  0.960137  0.957639  0.967469  0.995083
#
# [44784 rows x 7215 columns]

# %%
s = setup(data=df_train, target='target', session_id=123, n_jobs=1)
# Out:
# <style type="text/css">
# #T_8b81c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8b81c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b81c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8b81c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b81c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b81c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8b81c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b81c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8b81c_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b81c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8b81c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b81c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8b81c_row3_col1" class="data row3 col1" >(44784, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b81c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8b81c_row4_col1" class="data row4 col1" >(44784, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b81c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8b81c_row5_col1" class="data row5 col1" >(31348, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b81c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8b81c_row6_col1" class="data row6 col1" >(13436, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b81c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8b81c_row7_col1" class="data row7 col1" >7214</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8b81c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_8b81c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8b81c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_8b81c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8b81c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_8b81c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8b81c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_8b81c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8b81c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_8b81c_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8b81c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_8b81c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8b81c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_8b81c_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8b81c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_8b81c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8b81c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_8b81c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8b81c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_8b81c_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_8b81c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8b81c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_8b81c_row18_col1" class="data row18 col1" >bab5</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp = RegressionExperiment()
exp.setup(data=df_train, target='target', session_id=123)
# Out:
# <style type="text/css">
# #T_cc020_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cc020">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc020_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cc020_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc020_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc020_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cc020_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc020_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cc020_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc020_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cc020_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc020_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cc020_row3_col1" class="data row3 col1" >(44784, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc020_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cc020_row4_col1" class="data row4 col1" >(44784, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc020_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cc020_row5_col1" class="data row5 col1" >(31348, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc020_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cc020_row6_col1" class="data row6 col1" >(13436, 7215)</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cc020_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_cc020_row7_col1" class="data row7 col1" >7214</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cc020_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_cc020_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cc020_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_cc020_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cc020_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_cc020_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cc020_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_cc020_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cc020_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_cc020_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cc020_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_cc020_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cc020_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_cc020_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cc020_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_cc020_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cc020_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_cc020_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cc020_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_cc020_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cc020_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cc020_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_cc020_row18_col1" class="data row18 col1" >1567</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 22:34:18
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# <style type="text/css">
# #T_16ac1 th {
#   text-align: left;
# }
# #T_16ac1_row0_col0, #T_16ac1_row0_col1, #T_16ac1_row0_col2, #T_16ac1_row0_col3, #T_16ac1_row0_col4, #T_16ac1_row0_col5, #T_16ac1_row0_col6, #T_16ac1_row0_col7, #T_16ac1_row1_col0, #T_16ac1_row1_col1, #T_16ac1_row1_col2, #T_16ac1_row1_col3, #T_16ac1_row1_col4, #T_16ac1_row1_col5, #T_16ac1_row1_col6, #T_16ac1_row1_col7, #T_16ac1_row2_col0, #T_16ac1_row2_col1, #T_16ac1_row2_col2, #T_16ac1_row2_col3, #T_16ac1_row2_col4, #T_16ac1_row2_col5, #T_16ac1_row2_col6, #T_16ac1_row2_col7, #T_16ac1_row3_col0, #T_16ac1_row3_col1, #T_16ac1_row3_col2, #T_16ac1_row3_col3, #T_16ac1_row3_col4, #T_16ac1_row3_col5, #T_16ac1_row3_col6, #T_16ac1_row3_col7, #T_16ac1_row4_col0, #T_16ac1_row4_col1, #T_16ac1_row4_col2, #T_16ac1_row4_col3, #T_16ac1_row4_col4, #T_16ac1_row4_col5, #T_16ac1_row4_col6, #T_16ac1_row4_col7, #T_16ac1_row5_col0, #T_16ac1_row5_col1, #T_16ac1_row5_col2, #T_16ac1_row5_col3, #T_16ac1_row5_col4, #T_16ac1_row5_col5, #T_16ac1_row5_col6, #T_16ac1_row5_col7, #T_16ac1_row6_col0, #T_16ac1_row6_col1, #T_16ac1_row6_col2, #T_16ac1_row6_col3, #T_16ac1_row6_col4, #T_16ac1_row6_col5, #T_16ac1_row6_col6, #T_16ac1_row6_col7, #T_16ac1_row7_col0, #T_16ac1_row7_col1, #T_16ac1_row7_col2, #T_16ac1_row7_col3, #T_16ac1_row7_col4, #T_16ac1_row7_col5, #T_16ac1_row7_col6, #T_16ac1_row7_col7, #T_16ac1_row8_col0, #T_16ac1_row8_col1, #T_16ac1_row8_col2, #T_16ac1_row8_col3, #T_16ac1_row8_col4, #T_16ac1_row8_col5, #T_16ac1_row8_col6, #T_16ac1_row8_col7, #T_16ac1_row9_col0, #T_16ac1_row9_col1, #T_16ac1_row9_col2, #T_16ac1_row9_col3, #T_16ac1_row9_col4, #T_16ac1_row9_col5, #T_16ac1_row9_col6, #T_16ac1_row9_col7, #T_16ac1_row10_col0, #T_16ac1_row10_col1, #T_16ac1_row10_col2, #T_16ac1_row10_col3, #T_16ac1_row10_col4, #T_16ac1_row10_col5, #T_16ac1_row10_col6, #T_16ac1_row10_col7, #T_16ac1_row11_col0, #T_16ac1_row11_col1, #T_16ac1_row11_col2, #T_16ac1_row11_col3, #T_16ac1_row11_col4, #T_16ac1_row11_col5, #T_16ac1_row11_col6, #T_16ac1_row11_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_16ac1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16ac1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_16ac1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_16ac1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_16ac1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_16ac1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_16ac1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_16ac1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_16ac1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16ac1_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_16ac1_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_16ac1_row0_col1" class="data row0 col1" >0.0758</td>
#       <td id="T_16ac1_row0_col2" class="data row0 col2" >0.0165</td>
#       <td id="T_16ac1_row0_col3" class="data row0 col3" >0.1271</td>
#       <td id="T_16ac1_row0_col4" class="data row0 col4" >0.9777</td>
#       <td id="T_16ac1_row0_col5" class="data row0 col5" >0.0657</td>
#       <td id="T_16ac1_row0_col6" class="data row0 col6" >1.6150</td>
#       <td id="T_16ac1_row0_col7" class="data row0 col7" >39.9000</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_16ac1_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_16ac1_row1_col1" class="data row1 col1" >0.0758</td>
#       <td id="T_16ac1_row1_col2" class="data row1 col2" >0.0165</td>
#       <td id="T_16ac1_row1_col3" class="data row1 col3" >0.1271</td>
#       <td id="T_16ac1_row1_col4" class="data row1 col4" >0.9777</td>
#       <td id="T_16ac1_row1_col5" class="data row1 col5" >0.0657</td>
#       <td id="T_16ac1_row1_col6" class="data row1 col6" >1.6157</td>
#       <td id="T_16ac1_row1_col7" class="data row1 col7" >247.5040</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_16ac1_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_16ac1_row2_col1" class="data row2 col1" >0.0817</td>
#       <td id="T_16ac1_row2_col2" class="data row2 col2" >0.0191</td>
#       <td id="T_16ac1_row2_col3" class="data row2 col3" >0.1362</td>
#       <td id="T_16ac1_row2_col4" class="data row2 col4" >0.9741</td>
#       <td id="T_16ac1_row2_col5" class="data row2 col5" >0.0696</td>
#       <td id="T_16ac1_row2_col6" class="data row2 col6" >1.9351</td>
#       <td id="T_16ac1_row2_col7" class="data row2 col7" >40.9500</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_16ac1_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_16ac1_row3_col1" class="data row3 col1" >0.0870</td>
#       <td id="T_16ac1_row3_col2" class="data row3 col2" >0.0228</td>
#       <td id="T_16ac1_row3_col3" class="data row3 col3" >0.1497</td>
#       <td id="T_16ac1_row3_col4" class="data row3 col4" >0.9693</td>
#       <td id="T_16ac1_row3_col5" class="data row3 col5" >0.0757</td>
#       <td id="T_16ac1_row3_col6" class="data row3 col6" >1.7763</td>
#       <td id="T_16ac1_row3_col7" class="data row3 col7" >130.8850</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row4" class="row_heading level0 row4" >par</th>
#       <td id="T_16ac1_row4_col0" class="data row4 col0" >Passive Aggressive Regressor</td>
#       <td id="T_16ac1_row4_col1" class="data row4 col1" >0.1092</td>
#       <td id="T_16ac1_row4_col2" class="data row4 col2" >0.0257</td>
#       <td id="T_16ac1_row4_col3" class="data row4 col3" >0.1599</td>
#       <td id="T_16ac1_row4_col4" class="data row4 col4" >0.9655</td>
#       <td id="T_16ac1_row4_col5" class="data row4 col5" >0.0876</td>
#       <td id="T_16ac1_row4_col6" class="data row4 col6" >2.4651</td>
#       <td id="T_16ac1_row4_col7" class="data row4 col7" >89.7630</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_16ac1_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_16ac1_row5_col1" class="data row5 col1" >0.1246</td>
#       <td id="T_16ac1_row5_col2" class="data row5 col2" >0.0405</td>
#       <td id="T_16ac1_row5_col3" class="data row5 col3" >0.2008</td>
#       <td id="T_16ac1_row5_col4" class="data row5 col4" >0.9457</td>
#       <td id="T_16ac1_row5_col5" class="data row5 col5" >0.0971</td>
#       <td id="T_16ac1_row5_col6" class="data row5 col6" >2.3843</td>
#       <td id="T_16ac1_row5_col7" class="data row5 col7" >1132.8140</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row6" class="row_heading level0 row6" >dt</th>
#       <td id="T_16ac1_row6_col0" class="data row6 col0" >Decision Tree Regressor</td>
#       <td id="T_16ac1_row6_col1" class="data row6 col1" >0.1770</td>
#       <td id="T_16ac1_row6_col2" class="data row6 col2" >0.0592</td>
#       <td id="T_16ac1_row6_col3" class="data row6 col3" >0.2433</td>
#       <td id="T_16ac1_row6_col4" class="data row6 col4" >0.9204</td>
#       <td id="T_16ac1_row6_col5" class="data row6 col5" >0.1367</td>
#       <td id="T_16ac1_row6_col6" class="data row6 col6" >5.8922</td>
#       <td id="T_16ac1_row6_col7" class="data row6 col7" >574.1160</td>
#     </tr>
#     <tr>
#       <th id="T_16ac1_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_16ac1_row7_col0" class="data row7 col0" >K Neighbors Regressor</td>
#       <td id="T_16ac1_row7_col1" class="data row7 col1" >0.2314</td>
#       <td id="T_16ac1_row7_col2" class="data row7 col2" >0.1181</td>
#       <td id="T_16ac1_row7_col3" class="data row7 col3" >0.3435</td>
#       <td id="T_16ac1_row7_col4" class="data row7 col4" >0.8414</td>
#       <td id="T_16ac1_row7_col5" class="data row7 col5" >0.1836</td>
#       <td id="T_16ac1_row7_col6" class="data row7 col6" >5.9535</td>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]
