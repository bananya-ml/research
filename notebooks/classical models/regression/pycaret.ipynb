# %%
import pandas as pd
from pycaret.regression import setup, RegressionExperiment, compare_models, predict_model
from sklearn.decomposition import PCA
import numpy as np

# %%
def prepare_data(df):
    expanded_df = pd.DataFrame(df['flux'].tolist(), index=df.index)
    df = df.drop(columns=['source_id','spectraltype_esphs','Cat','flux'])
    df = pd.concat([df, expanded_df], axis=1)
    return df

# %%
train_data = pd.read_parquet('../../../data/Gaia DR3/train.parquet')
test_data = pd.read_parquet('../../../data/Gaia DR3/test.parquet')

train_df = prepare_data(train_data)
test_df = prepare_data(test_data)

pca = PCA(n_components=1)

# %%
x_train = train_df.iloc[:,3:]
y_train = np.vstack(train_df[['teff_gspphot','logg_gspphot','mh_gspphot']].values)

x_test = test_df.iloc[:,3:]
y_test = np.vstack(test_df[['teff_gspphot','logg_gspphot','mh_gspphot']].values)

# standardize the labels
mean_train = np.mean(y_train, axis=0)
std_train = np.std(y_train, axis=0)

mean_test = np.mean(y_test, axis=0)
std_test = np.std(y_test, axis=0)

y_train = (y_train - mean_train) / std_train
y_test = (y_test - mean_test) / std_test

# Transform into a single value
y_train = pca.fit_transform(y_train)
y_test = pca.fit_transform(y_test)


# Define the number of output labels
num_labels = y_train.shape[1]
num_fluxes = x_train.shape[1]

print('Each spectrum contains ' + str(num_fluxes) + ' wavelength bins')
print('Training set includes ' + str(x_train.shape[0]) + ' spectra.')
print('Test set includes ' + str(x_test.shape[0]) + ' spectra.')
# Out:
# Each spectrum contains 343 wavelength bins
# Training set includes 14101 spectra.
# Test set includes 3526 spectra.

# %%
df_train = pd.concat([pd.DataFrame(x_train), pd.DataFrame(y_train, columns=['target'])], axis=1)
df_test = pd.concat([pd.DataFrame(x_test), pd.DataFrame(y_test, columns=['target'])], axis=1)

# %%
s = setup(data=df_train, target='target', session_id=123, n_jobs=1)
# Out:
# <style type="text/css">
# #T_43cad_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_43cad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43cad_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_43cad_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43cad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43cad_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_43cad_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43cad_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_43cad_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43cad_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_43cad_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43cad_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_43cad_row3_col1" class="data row3 col1" >(14101, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43cad_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_43cad_row4_col1" class="data row4 col1" >(14101, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43cad_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_43cad_row5_col1" class="data row5 col1" >(9870, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43cad_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_43cad_row6_col1" class="data row6 col1" >(4231, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43cad_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_43cad_row7_col1" class="data row7 col1" >343</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43cad_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_43cad_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43cad_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_43cad_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_43cad_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_43cad_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_43cad_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_43cad_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_43cad_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_43cad_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_43cad_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_43cad_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_43cad_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_43cad_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_43cad_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_43cad_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_43cad_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_43cad_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_43cad_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_43cad_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_43cad_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_43cad_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_43cad_row18_col1" class="data row18 col1" >db48</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp = RegressionExperiment()
exp.setup(data=df_train, target='target', session_id=123)
# Out:
# <style type="text/css">
# #T_729ba_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_729ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_729ba_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_729ba_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_729ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_729ba_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_729ba_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_729ba_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_729ba_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_729ba_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_729ba_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_729ba_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_729ba_row3_col1" class="data row3 col1" >(14101, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_729ba_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_729ba_row4_col1" class="data row4 col1" >(14101, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_729ba_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_729ba_row5_col1" class="data row5 col1" >(9870, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_729ba_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_729ba_row6_col1" class="data row6 col1" >(4231, 344)</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_729ba_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_729ba_row7_col1" class="data row7 col1" >343</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_729ba_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_729ba_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_729ba_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_729ba_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_729ba_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_729ba_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_729ba_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_729ba_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_729ba_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_729ba_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_729ba_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_729ba_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_729ba_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_729ba_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_729ba_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_729ba_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_729ba_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_729ba_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_729ba_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_729ba_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_729ba_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_729ba_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_729ba_row18_col1" class="data row18 col1" >94dc</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ff4a7 th {
#   text-align: left;
# }
# #T_ff4a7_row0_col0, #T_ff4a7_row0_col5, #T_ff4a7_row0_col6, #T_ff4a7_row1_col0, #T_ff4a7_row1_col1, #T_ff4a7_row1_col2, #T_ff4a7_row1_col3, #T_ff4a7_row1_col4, #T_ff4a7_row1_col5, #T_ff4a7_row1_col6, #T_ff4a7_row2_col0, #T_ff4a7_row2_col1, #T_ff4a7_row2_col2, #T_ff4a7_row2_col3, #T_ff4a7_row2_col4, #T_ff4a7_row2_col6, #T_ff4a7_row3_col0, #T_ff4a7_row3_col1, #T_ff4a7_row3_col2, #T_ff4a7_row3_col3, #T_ff4a7_row3_col4, #T_ff4a7_row3_col5, #T_ff4a7_row4_col0, #T_ff4a7_row4_col1, #T_ff4a7_row4_col2, #T_ff4a7_row4_col3, #T_ff4a7_row4_col4, #T_ff4a7_row4_col5, #T_ff4a7_row4_col6, #T_ff4a7_row5_col0, #T_ff4a7_row5_col1, #T_ff4a7_row5_col2, #T_ff4a7_row5_col3, #T_ff4a7_row5_col4, #T_ff4a7_row5_col5, #T_ff4a7_row6_col0, #T_ff4a7_row6_col1, #T_ff4a7_row6_col2, #T_ff4a7_row6_col3, #T_ff4a7_row6_col4, #T_ff4a7_row6_col5, #T_ff4a7_row7_col0, #T_ff4a7_row7_col1, #T_ff4a7_row7_col2, #T_ff4a7_row7_col3, #T_ff4a7_row7_col4, #T_ff4a7_row7_col5, #T_ff4a7_row8_col0, #T_ff4a7_row8_col1, #T_ff4a7_row8_col2, #T_ff4a7_row8_col3, #T_ff4a7_row8_col4, #T_ff4a7_row8_col5, #T_ff4a7_row9_col0, #T_ff4a7_row9_col1, #T_ff4a7_row9_col2, #T_ff4a7_row9_col3, #T_ff4a7_row9_col4, #T_ff4a7_row9_col5, #T_ff4a7_row10_col0, #T_ff4a7_row10_col1, #T_ff4a7_row10_col2, #T_ff4a7_row10_col3, #T_ff4a7_row10_col4, #T_ff4a7_row10_col5, #T_ff4a7_row11_col0, #T_ff4a7_row11_col1, #T_ff4a7_row11_col2, #T_ff4a7_row11_col3, #T_ff4a7_row11_col4, #T_ff4a7_row11_col5, #T_ff4a7_row12_col0, #T_ff4a7_row12_col1, #T_ff4a7_row12_col2, #T_ff4a7_row12_col3, #T_ff4a7_row12_col4, #T_ff4a7_row12_col5, #T_ff4a7_row13_col0, #T_ff4a7_row13_col1, #T_ff4a7_row13_col2, #T_ff4a7_row13_col3, #T_ff4a7_row13_col4, #T_ff4a7_row13_col5, #T_ff4a7_row14_col0, #T_ff4a7_row14_col1, #T_ff4a7_row14_col2, #T_ff4a7_row14_col3, #T_ff4a7_row14_col4, #T_ff4a7_row14_col5, #T_ff4a7_row15_col0, #T_ff4a7_row15_col1, #T_ff4a7_row15_col2, #T_ff4a7_row15_col3, #T_ff4a7_row15_col4, #T_ff4a7_row15_col5, #T_ff4a7_row15_col6, #T_ff4a7_row16_col0, #T_ff4a7_row16_col1, #T_ff4a7_row16_col2, #T_ff4a7_row16_col3, #T_ff4a7_row16_col4, #T_ff4a7_row16_col5, #T_ff4a7_row16_col6, #T_ff4a7_row17_col0, #T_ff4a7_row17_col1, #T_ff4a7_row17_col2, #T_ff4a7_row17_col3, #T_ff4a7_row17_col4, #T_ff4a7_row17_col5, #T_ff4a7_row17_col6, #T_ff4a7_row18_col0, #T_ff4a7_row18_col1, #T_ff4a7_row18_col2, #T_ff4a7_row18_col3, #T_ff4a7_row18_col4, #T_ff4a7_row18_col5, #T_ff4a7_row18_col6 {
#   text-align: left;
# }
# #T_ff4a7_row0_col1, #T_ff4a7_row0_col2, #T_ff4a7_row0_col3, #T_ff4a7_row0_col4, #T_ff4a7_row2_col5, #T_ff4a7_row3_col6, #T_ff4a7_row5_col6, #T_ff4a7_row6_col6, #T_ff4a7_row7_col6, #T_ff4a7_row8_col6, #T_ff4a7_row9_col6, #T_ff4a7_row10_col6, #T_ff4a7_row11_col6, #T_ff4a7_row12_col6, #T_ff4a7_row13_col6, #T_ff4a7_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff4a7_row0_col7, #T_ff4a7_row1_col7, #T_ff4a7_row2_col7, #T_ff4a7_row3_col7, #T_ff4a7_row4_col7, #T_ff4a7_row5_col7, #T_ff4a7_row6_col7, #T_ff4a7_row7_col7, #T_ff4a7_row8_col7, #T_ff4a7_row9_col7, #T_ff4a7_row10_col7, #T_ff4a7_row11_col7, #T_ff4a7_row12_col7, #T_ff4a7_row13_col7, #T_ff4a7_row15_col7, #T_ff4a7_row16_col7, #T_ff4a7_row17_col7, #T_ff4a7_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff4a7_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff4a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff4a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff4a7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff4a7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff4a7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff4a7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff4a7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff4a7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ff4a7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff4a7_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ff4a7_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ff4a7_row0_col1" class="data row0 col1" >0.5520</td>
#       <td id="T_ff4a7_row0_col2" class="data row0 col2" >0.8096</td>
#       <td id="T_ff4a7_row0_col3" class="data row0 col3" >0.8988</td>
#       <td id="T_ff4a7_row0_col4" class="data row0 col4" >0.3525</td>
#       <td id="T_ff4a7_row0_col5" class="data row0 col5" >0.3515</td>
#       <td id="T_ff4a7_row0_col6" class="data row0 col6" >2.6454</td>
#       <td id="T_ff4a7_row0_col7" class="data row0 col7" >4.9710</td>
#     </tr>
#     <tr>
#       <th id="T_ff4a7_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_ff4a7_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ff4a7_row1_col1" class="data row1 col1" >0.5676</td>
#       <td id="T_ff4a7_row1_col2" class="data row1 col2" >0.8725</td>
#       <td id="T_ff4a7_row1_col3" class="data row1 col3" >0.9334</td>
#       <td id="T_ff4a7_row1_col4" class="data row1 col4" >0.3018</td>
#       <td id="T_ff4a7_row1_col5" class="data row1 col5" >0.3412</td>
#       <td id="T_ff4a7_row1_col6" class="data row1 col6" >3.6637</td>
#       <td id="T_ff4a7_row1_col7" class="data row1 col7" >9.4930</td>
#     </tr>
#     <tr>
#       <th id="T_ff4a7_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_ff4a7_row2_col0" class="data row2 col0" >K Neighbors Regressor</td>
#       <td id="T_ff4a7_row2_col1" class="data row2 col1" >0.5849</td>
#       <td id="T_ff4a7_row2_col2" class="data row2 col2" >0.9374</td>
#       <td id="T_ff4a7_row2_col3" class="data row2 col3" >0.9677</td>
#       <td id="T_ff4a7_row2_col4" class="data row2 col4" >0.2495</td>
#       <td id="T_ff4a7_row2_col5" class="data row2 col5" >0.3398</td>
#       <td id="T_ff4a7_row2_col6" class="data row2 col6" >3.8082</td>
#       <td id="T_ff4a7_row2_col7" class="data row2 col7" >0.2710</td>
#     </tr>
#     <tr>
#       <th id="T_ff4a7_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_ff4a7_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_ff4a7_row3_col1" class="data row3 col1" >0.8074</td>
#       <td id="T_ff4a7_row3_col2" class="data row3 col2" >1.2516</td>
#       <td id="T_ff4a7_row3_col3" class="data row3 col3" >1.1184</td>
#       <td id="T_ff4a7_row3_col4" class="data row3 col4" >-0.0014</td>
#       <td id="T_ff4a7_row3_col5" class="data row3 col5" >0.6256</td>
#       <td id="T_ff4a7_row3_col6" class="data row3 col6" >1.0522</td>
#       <td id="T_ff4a7_row3_col7" class="data row3 col7" >0.5190</td>
#     </tr>
#     <tr>
#       <th id="T_ff4a7_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_ff4a7_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_ff4a7_row4_col1" class="data row4 col1" >0.8071</td>
#       <td id="T_ff4a7_row4_col2" class="data row4 col2" >1.2516</td>
#       <td id="T_ff4a7_row4_col3" class="data row4 col3" >1.1184</td>
#       <td id="T_ff4a7_row4_col4" class="data row4 col4" >-0.0014</td>
#       <td id="T_ff4a7_row4_col5" class="data row4 col5" >0.6236</td>
#       <td id="T_ff4a7_row4_col6" class="data row4 col6" >1.0752</td>
#       <td id="T_ff4a7_row4_col7" class="data row4 col7" >18.8470</td>
#     </tr>
#     <tr>
#       <th id="T_ff4a7_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_ff4a7_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_ff4a7_row5_col1" class="data row5 col1" >0.8074</td>
#       <td id="T_ff4a7_row5_col2" class="data row5 col2" >1.2516</td>
#       <td id="T_ff4a7_row5_col3" class="data row5 col3" >1.1184</td>
#       <td id="T_ff4a7_row5_col4" class="data row5 col4" >-0.0014</td>
#       <td id="T_ff4a7_row5_col5" class="data row5 col5" >0.6256</td>
#       <td id="T_f

# %% [markdown]
# ## Predict

# %%
predict_model(best, data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_947ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_947ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_947ef_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_947ef_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_947ef_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_947ef_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_947ef_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_947ef_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_947ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_947ef_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_947ef_row0_col1" class="data row0 col1" >0.5489</td>
#       <td id="T_947ef_row0_col2" class="data row0 col2" >0.8018</td>
#       <td id="T_947ef_row0_col3" class="data row0 col3" >0.8955</td>
#       <td id="T_947ef_row0_col4" class="data row0 col4" >0.3580</td>
#       <td id="T_947ef_row0_col5" class="data row0 col5" >0.3468</td>
#       <td id="T_947ef_row0_col6" class="data row0 col6" >2.1137</td>
#     </tr>
#   </tbody>
# </table>
#                  0             1             2             3             4  \
# 0     2.140608e-17  1.365276e-17  8.998306e-18  9.277905e-18  1.133764e-17
# 1     5.743483e-16  5.637122e-16  5.316359e-16  5.080654e-16  5.123901e-16
# 2     9.540365e-16  9.370028e-16  8.942922e-16  8.675982e-16  8.753908e-16
# 3     4.322730e-17  3.599028e-17  3.116138e-17  3.147355e-17  3.380242e-17
# 4     1.134171e-15  1.104958e-15  1.022256e-15  9.641852e-16  9.621754e-16
# ...            ...           ...           ...           ...           ...
# 3521  2.481654e-17  2.224579e-17  2.078612e-17  1.823804e-17  1.631545e-17
# 3522  2.100507e-14  2.111412e-14  1.965781e-14  1.800614e-14  1.759250e-14
# 3523  4.950771e-17  4.735013e-17  4.774364e-17  4.771116e-17  4.583606e-17
# 3524  4.047548e-14  4.102307e-14  3.667214e-14  3.226985e-14  3.214448e-14
# 3525  5.256810e-15  5.344842e-15  5.286329e-15  5.129632e-15  5.035812e-15
#
#                  5             6             7             8             9  \
# 0     1.236834e-17  1.210512e-17  1.104840e-17  1.005849e-17  1.006457e-17
# 1     5.203310e-16  5.116850e-16  4.899089e-16  4.942565e-16  5.246064e-16
# 2     8.860598e-16  8.863876e-16  8.799443e-16  9.082285e-16  9.587669e-16
# 3     3.458265e-17  3.315480e-17  3.060560e-17  3.091396e-17  3.615521e-17
# 4     9.662636e-16  9.512777e-16  9.316988e-16  9.557092e-16  9.853166e-16
# ...            ...           ...           ...           ...           ...
# 3521  1.758840e-17  2.190646e-17  2.471268e-17  2.304838e-17  1.938278e-17
# 3522  1.766060e-14  1.680955e-14  1.511526e-14  1.526317e-14  1.799432e-14
# 3523  4.318559e-17  4.302986e-17  4.524361e-17  4.818025e-17  5.006902e-17
# 3524  3.417008e-14  3.371515e-14  3.013685e-14  2.969429e-14  3.469891e-14
# 3525  4.928288e-15  4.729649e-15  4.464373e-15  4.488020e-15  4.844838e-15
#
#       ...           335           336           337           338  \
# 0     ...  1.875544e-17  1.888428e-17  1.936134e-17  2.002518e-17
# 1     ...  1.788671e-16  1.732059e-16  1.707564e-16  1.708296e-16
# 2     ...  8.802934e-16  8.855333e-16  9.017898e-16  9.214689e-16
# 3     ...  1.779722e-17  1.638334e-17  1.512725e-17  1.408430e-17
# 4     ...  1.517024e-16  1.455515e-16  1.424176e-16  1.418621e-16
# ...   ...           ...           ...           ...           ...
# 3521  ...  5.743371e-17  5.699121e-17  5.724090e-17  5.781109e-17
# 3522  ...  3.149228e-15  3.032727e-15  2.977191e-15  2.971463e-15
# 3523  ...  4.230342e-17  4.132579e-17  4.100531e-17  4.113372e-17
# 3524  ...  3.287420e-15  3.079038e-15  2.927607e-15  2.829557e-15
# 3525  ...  3.866634e-16  3.665626e-16  3.534014e-16  3.465343e-16
#
#                339           340           341           342    target  \
# 0     2.037434e-17  2.127749e-17  2.145453e-17  2.210674e-17 -0.211531
# 1     1.701658e-16  1.769846e-16  1.812655e-16  1.934178e-16 -0.277604
# 2     9.221377e-16  9.441346e-16  9.314883e-16  9.383808e-16 -1.705701
# 3     1.316753e-17  1.320554e-17  1.359484e-17  1.523197e-17  0.362757
# 4     1.413263e-16  1.477437e-16  1.527918e-16  1.651610e-16 -0.864140
# ...            ...           ...           ...           ...       ...
# 3521  5.744140e-17  5.878628e-17  5.845928e-17  5.990392e-17 -0.270653
# 3522  2.959201e-15  3.082453e-15  3.164294e-15  3.382208e-15 -0.988735
# 3523  4.087202e-17  4.214290e-17  4.251873e-17  4.444370e-17 -0.240389
# 3524  2.743425e-15  2.813259e-15  2.885701e-15  3.129216e-15 -1.497687
# 3525  3.404289e-16  3.524916e-16  3.632561e-16  3.936495e-16 -0.329395
#
#       prediction_label
# 0             0.043237
# 1            -0.362509
# 2            -1.786159
# 3             0.293711
# 4            -0.900459
# ...                ...
# 3521          0.652693
# 3522         -0.673666
# 3523         -0.049454
# 3524         -0.809178
# 3525         -1.029258
#
# [3526 rows x 345 columns]
